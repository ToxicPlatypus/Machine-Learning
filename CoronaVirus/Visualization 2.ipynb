# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\rafid\OneDrive\Desktop\ML Project\Bangla.csv")
data.head()
# Out:
#        Date Code Country Name Region  NewCase  CumulativeCase  NewDeath  \
# 0  1/3/2020   BD   Bangladesh  SEARO        0               0         0
# 1  1/4/2020   BD   Bangladesh  SEARO        0               0         0
# 2  1/5/2020   BD   Bangladesh  SEARO        0               0         0
# 3  1/6/2020   BD   Bangladesh  SEARO        0               0         0
# 4  1/7/2020   BD   Bangladesh  SEARO        0               0         0
#
#    CumulativeDeath
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
data.tail()
# Out:
#           Date Code Country Name Region  NewCase  CumulativeCase  NewDeath  \
# 305  11/3/2020   BD   Bangladesh  SEARO     1736          410988        25
# 306  11/4/2020   BD   Bangladesh  SEARO     1659          412647        17
# 307  11/5/2020   BD   Bangladesh  SEARO     1517          414164        21
# 308  11/6/2020   BD   Bangladesh  SEARO     1842          416006        17
# 309  11/7/2020   BD   Bangladesh  SEARO     1469          417475        15
#
#      CumulativeDeath
# 305             5966
# 306             5983
# 307             6004
# 308             6021
# 309             6036

# %%
data.describe()
# Out:
#            NewCase  CumulativeCase    NewDeath  CumulativeDeath
# count   310.000000      310.000000  310.000000       310.000000
# mean   1346.693548   138641.467742   19.470968      1924.390323
# std    1233.513956   151463.711024   17.341351      2141.224700
# min       0.000000        0.000000    0.000000         0.000000
# 25%       0.000000       18.750000    0.000000         1.250000
# 50%    1368.000000    58977.000000   20.000000       796.000000
# 75%    2486.500000   289759.750000   35.000000      3851.250000
# max    4019.000000   417475.000000   64.000000      6036.000000

# %%
data.isnull().sum()
# Out:
# Date               0
# Code               0
# Country Name       0
# Region             0
# NewCase            0
# CumulativeCase     0
# NewDeath           0
# CumulativeDeath    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Date', 'Code', 'Country Name', 'Region', 'NewCase', 'CumulativeCase',
#        'NewDeath', 'CumulativeDeath'],
#       dtype='object')

# %% [markdown]
# # Relating the variables with scatterplots

# %%
sns.relplot(x="NewCase", y="NewDeath", data = data)

# %%
sns.relplot(x="CumulativeCase", y="CumulativeDeath", data = data)

# %%
sns.pairplot(data)

# %%
sns.catplot(x='CumulativeCase', y='CumulativeDeath', data=data)

# %%
sns.catplot(x='NewCase', y='NewDeath', data=data)

# %%
sns.relplot(x="CumulativeCase", y="CumulativeDeath", hue='NewDeath', data = data)

# %%
sns.relplot(x="NewCase", y="NewDeath", hue='NewDeath', data = data)
