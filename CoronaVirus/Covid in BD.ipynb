# %%
import pandas as pd

# %%
covid = pd.read_csv(r'C:\Users\rafid\OneDrive\Desktop\ML Project\covid.csv')

# %%
#Having a glance at some of the records
covid.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
#Looking at the shape
covid.shape
# Out:
# (19496, 32)

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#Looking at the different locations
covid["location"].value_counts()
# Out:
# Russia            146
# Iceland           146
# Switzerland       146
# South Korea       146
# France            146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %%
#Checking if columns have null values
covid.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
#Getting the sum of null values across each column
covid.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# ...

# %%
#Getting the cases in India
bd_case=covid[covid["location"]=="Bangladesh"]

# %%
bd_case.head()
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1719      BGD  Bangladesh  2020-03-04            0          0             0
# 1720      BGD  Bangladesh  2020-03-05            0          0             0
# 1721      BGD  Bangladesh  2020-03-06            0          0             0
# 1722      BGD  Bangladesh  2020-03-07            0          0             0
# 1723      BGD  Bangladesh  2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1719           0                      NaN                    NaN
# 1720           0                      NaN                    NaN
# 1721           0                      NaN                    NaN
# 1722           0                      NaN                    NaN
# 1723           0                      NaN                    NaN
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
bd_case.tail()
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1796      BGD  Bangladesh  2020-05-20        25121       1251           370
# 1797      BGD  Bangladesh  2020-05-21        26738       1617           386
# 1798      BGD  Bangladesh  2020-05-22        28511       1773           408
# 1799      BGD  Bangladesh  2020-05-23        30205       1694           432
# 1800      BGD  Bangladesh  2020-05-24        32078       1873           452
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1796          21                  152.536                  7.596
# 1797          16                  162.354                  9.818
# 1798          22                  173.120                 10.766
# 1799          24                  183.406                 10.286
# 1800          20                  194.779                 11.373
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=bd_case)
plt.show()

# %%
#Making a dataframe for last 5 days
bd_last_5_days=bd_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(3,3)})
sns.lineplot(x="date",y="total_cases",data=bd_last_5_days)
plt.show()

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=bd_case)
plt.show()

# %%
#Total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=bd_last_5_days)
plt.show()

# %%
#Understanding cases of Bangladesh, India, Pakistan
bd_ind_pak=covid[(covid["location"] =="Bangladesh") | (covid["location"] =="India") | (covid["location"]=="Pakistan")]

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=bd_ind_pak,hue="date")
plt.show()

# %%
#Getting latest data
last_day_cases=covid[covid["date"]=="2020-05-24"]
last_day_cases
# Out:
#        iso_code      location        date  total_cases  new_cases  \
# 62          ABW         Aruba  2020-05-24          101          0
# 198         AFG   Afghanistan  2020-05-24         9998        782
# 262         AGO        Angola  2020-05-24           60          0
# 321         AIA      Anguilla  2020-05-24            3          0
# 398         ALB       Albania  2020-05-24          989          8
# ...         ...           ...         ...          ...        ...
# 19045       YEM         Yemen  2020-05-24          212          7
# 19153       ZAF  South Africa  2020-05-24        21343       1218
# 19220       ZMB        Zambia  2020-05-24          920          0
# 19285       ZWE      Zimbabwe  2020-05-24           56          0
# 19431  OWID_WRL         World  2020-05-24      5273572      97636
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 62                3           0                  945.994
# ...

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code                         location        date  total_cases  \
# 19431  OWID_WRL                            World  2020-05-24      5273572
# 18391       USA                    United States  2020-05-24      1622670
# 2655        BRA                           Brazil  2020-05-24       347398
# 15569       RUS                           Russia  2020-05-24       335882
# 9396        ITA                            Italy  2020-05-24       229327
# ...         ...                              ...         ...          ...
# 18723       VGB           British Virgin Islands  2020-05-24            8
# 1645        BES  Bonaire Sint Eustatius and Saba  2020-05-24            6
# 5543        ESH                   Western Sahara  2020-05-24            6
# 321         AIA                         Anguilla  2020-05-24            3
# 11086       LSO                          Lesotho  2020-05-24            2
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 18391      USA  United States  2020-05-24      1622670      21236
# 2655       BRA         Brazil  2020-05-24       347398      16508
# 15569      RUS         Russia  2020-05-24       335882       9434
# 9396       ITA          Italy  2020-05-24       229327        669
# 4613       DEU        Germany  2020-05-24       178281        431
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 18391         97087        1080                 4902.287
# 2655          22013         965                 1634.357
# 15569          3388         139                 2301.595
# 9396          32735         119                 3792.922
# 4613           8247          31                 2127.866
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 18391                 64.157                   293.312  ...         15.413
# ...

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
bd_case.head()
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1719      BGD  Bangladesh  2020-03-04            0          0             0
# 1720      BGD  Bangladesh  2020-03-05            0          0             0
# 1721      BGD  Bangladesh  2020-03-06            0          0             0
# 1722      BGD  Bangladesh  2020-03-07            0          0             0
# 1723      BGD  Bangladesh  2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1719           0                      NaN                    NaN
# 1720           0                      NaN                    NaN
# 1721           0                      NaN                    NaN
# 1722           0                      NaN                    NaN
# 1723           0                      NaN                    NaN
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
bd_case['date'] = pd.to_datetime(bd_case['date']) 
bd_case.head()
# Out:
# <ipython-input-28-eab9372faaf0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_case['date'] = pd.to_datetime(bd_case['date'])
#      iso_code    location       date  total_cases  new_cases  total_deaths  \
# 1719      BGD  Bangladesh 2020-03-04            0          0             0
# 1720      BGD  Bangladesh 2020-03-05            0          0             0
# 1721      BGD  Bangladesh 2020-03-06            0          0             0
# 1722      BGD  Bangladesh 2020-03-07            0          0             0
# 1723      BGD  Bangladesh 2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1719           0                      NaN                    NaN
# ...

# %%
bd_case.head()
# Out:
#      iso_code    location       date  total_cases  new_cases  total_deaths  \
# 1719      BGD  Bangladesh 2020-03-04            0          0             0
# 1720      BGD  Bangladesh 2020-03-05            0          0             0
# 1721      BGD  Bangladesh 2020-03-06            0          0             0
# 1722      BGD  Bangladesh 2020-03-07            0          0             0
# 1723      BGD  Bangladesh 2020-03-08            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1719           0                      NaN                    NaN
# 1720           0                      NaN                    NaN
# 1721           0                      NaN                    NaN
# 1722           0                      NaN                    NaN
# 1723           0                      NaN                    NaN
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#converting date-time to ordinal
bd_case['date']=bd_case['date'].map(dt.datetime.toordinal)
bd_case.head()
# Out:
# <ipython-input-30-84d7d7828da7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_case['date']=bd_case['date'].map(dt.datetime.toordinal)
#      iso_code    location    date  total_cases  new_cases  total_deaths  \
# 1719      BGD  Bangladesh  737488            0          0             0
# 1720      BGD  Bangladesh  737489            0          0             0
# 1721      BGD  Bangladesh  737490            0          0             0
# 1722      BGD  Bangladesh  737491            0          0             0
# 1723      BGD  Bangladesh  737492            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1719           0                      NaN                    NaN
# ...

# %%
#getting dependent variable and inpedent variable
x=bd_case['date']
y=bd_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
bd_case.tail()
# Out:
#      iso_code    location    date  total_cases  new_cases  total_deaths  \
# 1796      BGD  Bangladesh  737565        25121       1251           370
# 1797      BGD  Bangladesh  737566        26738       1617           386
# 1798      BGD  Bangladesh  737567        28511       1773           408
# 1799      BGD  Bangladesh  737568        30205       1694           432
# 1800      BGD  Bangladesh  737569        32078       1873           452
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 1796          21                  152.536                  7.596
# 1797          16                  162.354                  9.818
# 1798          22                  173.120                 10.766
# 1799          24                  183.406                 10.286
# 1800          20                  194.779                 11.373
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 1796                     2.247  ...          5.098          3.262
# ...

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 537623418283.86804

# %%
lr.predict(np.array([[737573]]))
# Out:
# array([[18632.92389989]])
